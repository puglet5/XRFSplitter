# %%
from app.utils import *

# %%
data = TableData("./fixtures/Results.csv")

# %%
data.sort("Pb", True)
# Out:
#      File #          DateTime Operator            Name ID Field1 Field2  \
# 91      514  01-02-2006 12:49     User  pbo-sio2-k2co3  4
# 90      513  01-02-2006 12:48     User  pbo-sio2-k2co3  4
# 87      510  01-02-2006 12:45     User  pbo-sio2-k2co3  4
# 89      512  01-02-2006 12:48     User  pbo-sio2-k2co3  4
# 92      515  01-02-2006 12:50     User  pbo-sio2-k2co3  4
# ...     ...               ...      ...             ... ..    ...    ...
# 1196   1729  01-01-2006 15:33     User      germanFlag  4
# 1207   1740  01-02-2006 14:33     User      germanFlag  4
# 1549   2082  01-14-2006 11:14     User      germanFlag  4
# 1568   2101  01-23-2006 15:36     User      germanFlag  4
# 1569   2102  01-23-2006 15:37     User      germanFlag  4
#
#               Application             Method ElapsedTime  ...     Tl  Tl Err  \
# 91               Alloys 2      HiZ SnSolders         4.0  ...
# 90    Alloys SMARTGrade 2      HiZ SnSolders         2.0  ...
# ...
