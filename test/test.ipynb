# %%
from app.utils import *
import pandas as pd
import numpy as np
import functools

# %%
def sorter(x, y):
    strx: str = str(x[1]).strip()
    stry: str = str(y[1]).strip()

    try:
        x = float(strx)
        y = float(stry)

        if x < y:
            return -1
        elif x > y:
            return 1
        else:
            return 0

    except ValueError:
        x = strx
        y = stry

    if x == "" and y == "< LOD":
        return -1
    if y == "" and x == "< LOD":
        return 1
    if x == "" or x == "< LOD" and y != x:
        return -1
    if y == "" or y == "< LOD" and x != y:
        return 1
    if x < y:
        return -1
    elif x > y:
        return 1
    else:
        return 0


key = functools.cmp_to_key(sorter)

# %%
filepath = "./fixtures/01968-GeoMining.pdz"
pdz = PDZFile(filepath)

csv_data = construct_data(Path("./fixtures/results.csv"))
selected_data = select_data(csv_data, [0, 3000])
df = pd.read_csv(data_to_csv(selected_data), dtype=str).fillna("")

arr = df["Pb"].tolist()
df = pd.DataFrame(df, index=[b[0] for b in sorted(enumerate(arr), key=key)])
df.reset_index(drop=True,inplace=True)
df
# Out:
#   File #          DateTime Operator        Name ID Field1 Field2  \
# 0    422  11-22-2022 17:43     User  zhelezyaka  1
# 1    425  11-22-2022 17:49     User  zhelezyaka  1
# 2    424  11-22-2022 17:48     User  zhelezyaka  1
# 3    427  11-23-2022 16:30     User  zhelezyaka  1
# 4    429  11-23-2022 16:34     User  zhelezyaka  1
# 5    428  11-23-2022 16:32     User  zhelezyaka  1
# 6    426  11-23-2022 16:28     User  zhelezyaka  1
# 7    423  11-22-2022 17:44     User  zhelezyaka  1
#
#                Application             Method ElapsedTime  ...     Tl  Tl Err  \
# 0  Shavings and Turnings 2      MultiMatrix40         1.0  ...
# 1                GeoMining  OxideConcentrates        90.0  ...  < LOD  0.0011
# 2  Shavings and Turnings 2    MultiMatrix4015        91.0  ...
# 3                GeoMining                                 ...  < LOD  0.0021
# 4                GeoMining                                 ...  < LOD  0.0031
# 5                GeoMining  OxideConcentrates        90.0  ...  < LOD  0.0041
# 6                GeoMining  OxideConcentrates        90.0  ...  < LOD  0.0041
# 7  Shavings and Turnings 2      MultiMatrix40         2.0  ...
#
#         Pb   Pb Err      Bi   Bi Err      U   U Err Multiplier Cal Check
# 0    < LOD  25.4066   < LOD  13.9670                         2    Passed
# 1   0.0144   0.0011   < LOD   0.0011  < LOD  0.0009          2    Passed
# 2   0.4554   0.1996   < LOD   0.0893                         2    Passed
# 3   9.4335   0.0230  0.0095   0.0049  < LOD  0.0013          2    Passed
# 4  17.3005   0.0384  0.0128   0.0080  < LOD  0.0018          2    Passed
# 5  23.8131   0.0520   < LOD   0.0113  < LOD  0.0023          2    Passed
# 6  28.0739   0.0620  0.0283   0.0117  < LOD  0.0023          2    Passed
# 7  42.0970  29.2208   < LOD  16.5311                         2    Passed
#
# [8 rows x 114 columns]
