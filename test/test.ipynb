# %%
from app.utils import *
import os

# %%
data = TableData("./fixtures/Results.csv")

# %%
from numpy import NaN, nan


data.toggle_columns(list(set(RESULTS_JUNK) | set(RESULT_KEYS_ERR)), False)
df = data.toggle_lod(False).iloc[:, :]
df
# Out:
#      File # Li Be C  Mg     MgO Al   Al2O3       Si     SiO2  ... Os Ir Pt Au  \
# 1572   2105                                                   ...
# 1571   2104              0.8268                               ...
# 1570   2103              1.3664                       0.6882  ...
# 1569   2102                                                   ...
# 1568   2101                                                   ...
# ...     ... .. .. .. ..     ... ..     ...      ...      ...  ... .. .. .. ..
# 4       426                                          30.9298  ...
# 3       425                         0.3981           79.1598  ...
# 2       424                                 97.5537           ...
# 1       423                                                   ...
# 0       422                                                   ...
#
#      Hg Tl       Pb      Bi Th U
# 1572        40.5181  0.0307
# 1571         0.0035
# 1570
# 1569
# 1568
# ...  .. ..      ...     ... .. ..
# ...

# %%
data.toggle_columns(list(set(RESULTS_JUNK) | set(RESULT_KEYS_ERR)), False)
df = data.toggle_lod(False).iloc[:, :]
df = df.replace("", nan)
df = df.dropna(subset=df.columns.difference(["File #"]), how="all", axis=0)
df.fillna("")
# Out:
#      File # Li Be C  Mg     MgO Al   Al2O3       Si     SiO2  ... Os Ir Pt Au  \
# 1572   2105                                                   ...
# 1571   2104              0.8268                               ...
# 1570   2103              1.3664                       0.6882  ...
# 1569   2102                                                   ...
# 1568   2101                                                   ...
# ...     ... .. .. .. ..     ... ..     ...      ...      ...  ... .. .. .. ..
# 4       426                                          30.9298  ...
# 3       425                         0.3981           79.1598  ...
# 2       424                                 97.5537           ...
# 1       423                                                   ...
# 0       422                                                   ...
#
#      Hg Tl       Pb      Bi Th U
# 1572        40.5181  0.0307
# 1571         0.0035
# 1570
# 1569
# 1568
# ...  .. ..      ...     ... .. ..
# ...

# %%
import re

spectrum_label = "211"

files = [
    filename
    for filename in os.listdir("/home/puglet5/Documents/PROJ/test_data/smalts pdz")
    if filename.endswith(".pdz")
]

p = re.compile(f'^([0]+){spectrum_label}-')

files_re = [s for s in files if p.match(s) ]
files_re.__len__()
# Out:
# 1
